# %%
#import libaries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#adding eth file in dataframe
df = pd.read_csv("C:/Users/Administrator/Documents/DownlaodsFromKavit/Downloads/datasets/Datasets/diabetic_data.csv")

# %%
df.head(10)
# Out:
#    encounter_id  patient_nbr             race  gender       age weight  \
# 0       2278392      8222157        Caucasian  Female    [0-10)      ?
# 1        149190     55629189        Caucasian  Female   [10-20)      ?
# 2         64410     86047875  AfricanAmerican  Female   [20-30)      ?
# 3        500364     82442376        Caucasian    Male   [30-40)      ?
# 4         16680     42519267        Caucasian    Male   [40-50)      ?
# 5         35754     82637451        Caucasian    Male   [50-60)      ?
# 6         55842     84259809        Caucasian    Male   [60-70)      ?
# 7         63768    114882984        Caucasian    Male   [70-80)      ?
# 8         12522     48330783        Caucasian  Female   [80-90)      ?
# 9         15738     63555939        Caucasian  Female  [90-100)      ?
#
#    admission_type_id  discharge_disposition_id  admission_source_id  \
# 0                  6                        25                    1
# ...

# %%
df.head(10).T
# Out:
#                                                  0          1  \
# encounter_id                               2278392     149190
# patient_nbr                                8222157   55629189
# race                                     Caucasian  Caucasian
# gender                                      Female     Female
# age                                         [0-10)    [10-20)
# weight                                           ?          ?
# admission_type_id                                6          1
# discharge_disposition_id                        25          1
# admission_source_id                              1          7
# time_in_hospital                                 1          3
# payer_code                                       ?          ?
# medical_specialty         Pediatrics-Endocrinology          ?
# num_lab_procedures                              41         59
# num_procedures                                   0          0
# ...

# %%
df.shape
# Out:
# (101766, 50)

# %%
df.dtypes
# Out:
# encounter_id                 int64
# patient_nbr                  int64
# race                        object
# gender                      object
# age                         object
# weight                      object
# admission_type_id            int64
# discharge_disposition_id     int64
# admission_source_id          int64
# time_in_hospital             int64
# payer_code                  object
# medical_specialty           object
# num_lab_procedures           int64
# num_procedures               int64
# num_medications              int64
# number_outpatient            int64
# number_emergency             int64
# number_inpatient             int64
# diag_1                      object
# diag_2                      object
# diag_3                      object
# number_diagnoses             int64
# max_glu_serum               object
# A1Cresult                   object
# metformin                   object
# repaglinide                 object
# nateglinide                 object
# ...

# %%
#finding teh missing values and missin gvalues are denoted by '?'

for col in df.columns:
    if df[col].dtype == object:
        print(col,df[col][df[col] == "?"].count())
# Out:
# race 2273
# gender 0
# age 0
# weight 98569
# payer_code 40256
# medical_specialty 49949
# diag_1 21
# diag_2 358
# diag_3 1423
# max_glu_serum 0
# A1Cresult 0
# metformin 0
# repaglinide 0
# nateglinide 0
# chlorpropamide 0
# glimepiride 0
# acetohexamide 0
# glipizide 0
# glyburide 0
# tolbutamide 0
# pioglitazone 0
# rosiglitazone 0
# acarbose 0
# miglitol 0
# troglitazone 0
# tolazamide 0
# examide 0
# citoglipton 0
# insulin 0
# glyburide-metformin 0
# glipizide-metformin 0
# glimepiride-pioglitazone 0
# metformin-rosiglitazone 0
# metformin-pioglitazone 0
# change 0
# diabetesMed 0
# readmitted 0

# %%
#gender has value as 'INVALID/UNKNOWN"
print('gender',df['gender'][df['gender'] == "Unknown/Invalid"].count())
# Out:
# gender 3

# %%
#as weight has 98% missing values so it is better to drop this column 
df = df.drop(['weight','payer_code','medical_specialty'],axis=1)

# %%
for col in df.columns:
    if df[col].dtype == object:
        print(col,df[col][df[col] == "?"].count())
# Out:
# race 2273
# gender 0
# age 0
# diag_1 21
# diag_2 358
# diag_3 1423
# max_glu_serum 0
# A1Cresult 0
# metformin 0
# repaglinide 0
# nateglinide 0
# chlorpropamide 0
# glimepiride 0
# acetohexamide 0
# glipizide 0
# glyburide 0
# tolbutamide 0
# pioglitazone 0
# rosiglitazone 0
# acarbose 0
# miglitol 0
# troglitazone 0
# tolazamide 0
# examide 0
# citoglipton 0
# insulin 0
# glyburide-metformin 0
# glipizide-metformin 0
# glimepiride-pioglitazone 0
# metformin-rosiglitazone 0
# metformin-pioglitazone 0
# change 0
# diabetesMed 0
# readmitted 0

# %%
#let us drop the row with missing values from column reace,gender,diag_1, diag_2, diag_3

# Identify rows to drop
drop_Idx = set(df[(df['diag_1'] == '?') & (df['diag_2'] == '?') & (df['diag_3'] == '?')].index)

# Union with additional rows based on other conditions
drop_Idx = drop_Idx.union(set(df[df['diag_1'] == '?'].index))
drop_Idx = drop_Idx.union(set(df[df['diag_2'] == '?'].index))
drop_Idx = drop_Idx.union(set(df[df['diag_3'] == '?'].index))
drop_Idx = drop_Idx.union(set(df[df['race'] == '?'].index))
drop_Idx = drop_Idx.union(set(df[df['discharge_disposition_id'] == 11].index))
drop_Idx = drop_Idx.union(set(df[df['gender'] == 'Unknown/Invalid'].index))

# Ensure indices are within bounds
drop_Idx = [idx for idx in drop_Idx if idx in df.index]

# Create list of valid indices
new_Idx = list(set(df.index) - set(drop_Idx))

# Check if there are any valid indices left
if not new_Idx:
    raise ValueError("No valid indices remaining after filtering.")

# Filter DataFrame to keep only valid rows
df = df.iloc[new_Idx]

# Reset index to ensure it’s continuous and clean
df = df.reset_index(drop=True)

# %%
df = df.drop(['citoglipton', 'examide'], axis = 1)

# %%
for col in df.columns:
    if df[col].dtype == object:
         print(col,df[col][df[col] == '?'].count())
            
print('gender', df['gender'][df['gender'] == 'Unknown/Invalid'].count())
# Out:
# race 0
# gender 0
# age 0
# diag_1 0
# diag_2 0
# diag_3 0
# max_glu_serum 0
# A1Cresult 0
# metformin 0
# repaglinide 0
# nateglinide 0
# chlorpropamide 0
# glimepiride 0
# acetohexamide 0
# glipizide 0
# glyburide 0
# tolbutamide 0
# pioglitazone 0
# rosiglitazone 0
# acarbose 0
# miglitol 0
# troglitazone 0
# tolazamide 0
# insulin 0
# glyburide-metformin 0
# glipizide-metformin 0
# glimepiride-pioglitazone 0
# metformin-rosiglitazone 0
# metformin-pioglitazone 0
# change 0
# diabetesMed 0
# readmitted 0
# gender 0

# %%
# code age intervals [0-10) - [90-100) from 1-10
for i in range(0,10):
    df['age'] = df['age'].replace('['+str(10*i)+'-'+str(10*(i+1))+')', i+1)
df['age'].value_counts()
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_22744\230174704.py:3: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['age'] = df['age'].replace('['+str(10*i)+'-'+str(10*(i+1))+')', i+1)
# age
# 8     24815
# 7     21521
# 6     16546
# 9     16223
# 5      9208
# 4      3538
# 10     2594
# 3      1471
# 2       466
# 1        64
# Name: count, dtype: int64

# %%
df2 = df.drop_duplicates(subset= ['patient_nbr'], keep = 'first')
df2.shape
(70442, 55)
# Out:
# (70442, 55)

# %%
df.head().T
# Out:
#                                   0                1          2          3  \
# encounter_id                 149190            64410     500364      16680
# patient_nbr                55629189         86047875   82442376   42519267
# race                      Caucasian  AfricanAmerican  Caucasian  Caucasian
# gender                       Female           Female       Male       Male
# age                               2                3          4          5
# admission_type_id                 1                1          1          1
# discharge_disposition_id          1                1          1          1
# admission_source_id               7                7          7          7
# time_in_hospital                  3                2          2          1
# num_lab_procedures               59               11         44         51
# num_procedures                    0                5          1          0
# ...

# %%
df['readmitted'].value_counts()
# Out:
# readmitted
# NO     50731
# >30    34649
# <30    11066
# Name: count, dtype: int64

# %%
df['readmitted'] = df['readmitted'].replace('>30', 0)
df['readmitted'] = df['readmitted'].replace('<30', 1)
df['readmitted'] = df['readmitted'].replace('NO', 0)
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_22744\2457122364.py:3: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['readmitted'] = df['readmitted'].replace('NO', 0)

# %%
df.head().T
# Out:
#                                   0                1          2          3  \
# encounter_id                 149190            64410     500364      16680
# patient_nbr                55629189         86047875   82442376   42519267
# race                      Caucasian  AfricanAmerican  Caucasian  Caucasian
# gender                       Female           Female       Male       Male
# age                               2                3          4          5
# admission_type_id                 1                1          1          1
# discharge_disposition_id          1                1          1          1
# admission_source_id               7                7          7          7
# time_in_hospital                  3                2          2          1
# num_lab_procedures               59               11         44         51
# num_procedures                    0                5          1          0
# ...

# %%
df['max_glu_serum'].value_counts()
# Out:
# max_glu_serum
# Norm    2510
# >200    1404
# >300    1175
# Name: count, dtype: int64

# %%
df['max_glu_serum'] = df['max_glu_serum'].replace('NaN',0)
df['max_glu_serum'].value_counts()
# Out:
# max_glu_serum
# Norm    2510
# >200    1404
# >300    1175
# Name: count, dtype: int64

# %%
df.head().T
# Out:
#                                   0                1          2          3  \
# encounter_id                 149190            64410     500364      16680
# patient_nbr                55629189         86047875   82442376   42519267
# race                      Caucasian  AfricanAmerican  Caucasian  Caucasian
# gender                       Female           Female       Male       Male
# age                               2                3          4          5
# admission_type_id                 1                1          1          1
# discharge_disposition_id          1                1          1          1
# admission_source_id               7                7          7          7
# time_in_hospital                  3                2          2          1
# num_lab_procedures               59               11         44         51
# num_procedures                    0                5          1          0
# ...

# %%
df['max_glu_serum'].isna().sum()
# Out:
# 91357

# %%
#let fill it with a value 0
df.fillna(0,inplace=True)
df.head(10)
# Out:
#    encounter_id  patient_nbr             race  gender  age  admission_type_id  \
# 0        149190     55629189        Caucasian  Female    2                  1
# 1         64410     86047875  AfricanAmerican  Female    3                  1
# 2        500364     82442376        Caucasian    Male    4                  1
# 3         16680     42519267        Caucasian    Male    5                  1
# 4         35754     82637451        Caucasian    Male    6                  2
# 5         55842     84259809        Caucasian    Male    7                  3
# 6         63768    114882984        Caucasian    Male    8                  1
# 7         12522     48330783        Caucasian  Female    9                  2
# 8         15738     63555939        Caucasian  Female   10                  3
# 9         28236     89869032  AfricanAmerican  Female    5                  1
#
#    discharge_disposition_id  admission_source_id  time_in_hospital  \
# ...

# %%
import mysql.connector
import pandas as pd

# Create a connection to MySQL
connection = mysql.connector.connect(
    host="127.0.0.1",      # Replace with your MySQL host
    user="root",  # Replace with your MySQL username
    password="Universe@123",  # Replace with your MySQL password
    database="Healthcare"  # Replace with the target database
)

# Create a cursor object to execute SQL commands
cursor = connection.cursor()

# %%
heathcare_Data = pd.DataFrame(df)

# %%
heathcare_Data
# Out:
#        encounter_id  patient_nbr             race  gender  age  \
# 0            149190     55629189        Caucasian  Female    2
# 1             64410     86047875  AfricanAmerican  Female    3
# 2            500364     82442376        Caucasian    Male    4
# 3             16680     42519267        Caucasian    Male    5
# 4             35754     82637451        Caucasian    Male    6
# ...             ...          ...              ...     ...  ...
# 96441     443847548    100162476  AfricanAmerican    Male    8
# 96442     443847782     74694222  AfricanAmerican  Female    9
# 96443     443854148     41088789        Caucasian    Male    8
# 96444     443857166     31693671        Caucasian  Female    9
# 96445     443867222    175429310        Caucasian    Male    8
#
#        admission_type_id  discharge_disposition_id  admission_source_id  \
# 0                      1                         1                    7
# ...

# %%
heathcare_Data.to_csv("healthcare_Data.csv", index=False)
